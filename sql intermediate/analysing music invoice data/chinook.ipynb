# %% [markdown]
# # working with Larger Databases
# ### Refer to the database schema while studying this notebook
# ![Schema](schema.png)

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('chinook.db')

# %%
pd.read_sql_query("select * from sqlite_master where type='table';",conn)
# Out:
#      type            name        tbl_name  rootpage  \
# 0   table           album           album         2
# 1   table          artist          artist         3
# 2   table        customer        customer         4
# 3   table        employee        employee         5
# 4   table           genre           genre         6
# 5   table         invoice         invoice         7
# 6   table    invoice_line    invoice_line         8
# 7   table      media_type      media_type         9
# 8   table        playlist        playlist        10
# 9   table  playlist_track  playlist_track        11
# 10  table           track           track        13
#
#                                                   sql
# 0   CREATE TABLE [album]\n(\n    [album_id] INTEGE...
# 1   CREATE TABLE [artist]\n(\n    [artist_id] INTE...
# 2   CREATE TABLE [customer]\n(\n    [customer_id] ...
# 3   CREATE TABLE [employee]\n(\n    [employee_id] ...
# 4   CREATE TABLE [genre]\n(\n    [genre_id] INTEGE...
# 5   CREATE TABLE [invoice]\n(\n    [invoice_id] IN...
# 6   CREATE TABLE [invoice_line]\n(\n    [invoice_l...
# 7   CREATE TABLE [media_type]\n(\n    [media_type_...
# 8   CREATE TABLE [playlist]\n(\n    [playlist_id] ...
# 9   CREATE TABLE [playlist_track]\n(\n    [playlis...
# 10  CREATE TABLE [track]\n(\n    [track_id] INTEGE...

# %% [markdown]
# # Joining Three Tables
# Write a query that gathers data about the invoice with an invoice_id of 4. Include the following columns in order:
# - The **id of the track**, track_id.
# - The **name of the track**, track_name.
# - The **name of media type of the track**, track_type.
# - The **price that the customer paid for the track**, unit_price.
# - The **quantity of the track that was purchased**, quantity.
#
# merge the 3 tables: **invoice_line, track, and media_type**

# %%
q1 = '''
SELECT 
    il.track_id,
    t.name track_name,
    mt.name track_type,
    il.unit_price,
    il.quantity
FROM invoice_line il
INNER JOIN track t ON t.track_id = il.track_id
INNER JOIN media_type mt ON mt.media_type_id = t.media_type_id
where il.invoice_id = 4
'''
pd.read_sql_query(q1,conn)
# Out:
#    track_id                                         track_name  \
# 0      3448  Lamentations of Jeremiah, First Set \ Incipit ...
# 1      2560                                Violent Pornography
# 2      3336                                           War Pigs
# 3       829                                   Let's Get Rocked
# 4      1872                                           Attitude
# 5       748                                             Dealer
# 6      1778       You're What's Happening (In The World Today)
# 7      2514                                           Spoonman
#
#                  track_type  unit_price  quantity
# 0  Protected AAC audio file        0.99         1
# 1           MPEG audio file        0.99         1
# 2  Purchased AAC audio file        0.99         1
# 3           MPEG audio file        0.99         1
# 4           MPEG audio file        0.99         1
# 5           MPEG audio file        0.99         1
# 6           MPEG audio file        0.99         1
# 7           MPEG audio file        0.99         1

# %% [markdown]
# # Joining More Than Three Tables
# Add a column containing the artists name to the previous query.
# - The column should be called **artist_name**
# - The column should be placed between **track_name** and **track_type**
#
# merge the 5 tables: **invoice_line, track, media_type, album and artist**

# %%
q2 = '''
SELECT 
    il.track_id,
    t.name track_name,
    ar.name artist_name,
    mt.name track_type,
    il.unit_price,
    il.quantity
FROM invoice_line il
INNER JOIN track t ON t.track_id = il.track_id
INNER JOIN media_type mt ON mt.media_type_id = t.media_type_id
INNER JOIN album al ON al.album_id = t.album_id
INNER JOIN artist ar ON ar.artist_id = al.artist_id
where il.invoice_id = 4
'''
pd.read_sql_query(q2,conn)
# Out:
#    track_id                                         track_name  \
# 0      3448  Lamentations of Jeremiah, First Set \ Incipit ...
# 1      2560                                Violent Pornography
# 2      3336                                           War Pigs
# 3       829                                   Let's Get Rocked
# 4      1872                                           Attitude
# 5       748                                             Dealer
# 6      1778       You're What's Happening (In The World Today)
# 7      2514                                           Spoonman
#
#           artist_name                track_type  unit_price  quantity
# 0  The King's Singers  Protected AAC audio file        0.99         1
# 1    System Of A Down           MPEG audio file        0.99         1
# 2                Cake  Purchased AAC audio file        0.99         1
# 3         Def Leppard           MPEG audio file        0.99         1
# 4           Metallica           MPEG audio file        0.99         1
# 5         Deep Purple           MPEG audio file        0.99         1
# 6         Marvin Gaye           MPEG audio file        0.99         1
# 7         Soundgarden           MPEG audio file        0.99         1

# %% [markdown]
# # Combining Multiple Joins with Subqueries

# %% [markdown]
# ### list the top 10 artists, calculated by the number of times a track by that artist has been purchased.

# %%
q3 = '''
SELECT 
    ta.name artist,
    COUNT(*) tracks_purchased
FROM invoice_line il
INNER JOIN (
            SELECT
                ar.name,
                t.track_id
            FROM track t
            INNER JOIN album al ON al.album_id = t.album_id
            INNER JOIN artist ar ON ar.artist_id = al.artist_id
            ) ta 
            ON il.track_id = ta.track_id
GROUP BY 1
ORDER BY 2 DESC ;
'''
pd.read_sql_query(q3,conn)
# Out:
#                                                 artist  tracks_purchased
# 0                                                Queen               192
# 1                                         Jimi Hendrix               187
# 2                                              Nirvana               130
# 3                                Red Hot Chili Peppers               130
# 4                                            Pearl Jam               129
# 5                                                AC/DC               124
# 6                                        Guns N' Roses               124
# 7                                         Foo Fighters               121
# 8                                   The Rolling Stones               117
# 9                                            Metallica               106
# 10                                           Green Day               105
# 11                                              R.E.M.               104
# 12                                       Amy Winehouse                97
# 13                                            Godsmack                96
# 14                                        Eric Clapton                94
# 15                                    System Of A Down                93
# 16                                           Van Halen                93
# 17                                                 JET                90
# 18                                                  U2                89
# 19                                         Iron Maiden                84
# 20                                           The Doors                83
# 21                                           Aerosmith                80
# 22                                          The Police                80
# 23                                             The Who                76
# 24                                   Alanis Morissette                75
# 25                                       Frank Sinatra                74
# 26                                         Miles Davis                74
# 27                                           Scorpions                74
# 28                                           The Clash                72
# 29                                        Led Zeppelin                71
# ..                                                 ...               ...
# 100                                         Karsh Kale                 3
# 101                       Luciana Souza/Romero Lubambo                 3
# 102                        Nicolaus Esterhazy Sinfonia                 3
# 103                                         Passengers                 3
# 104                                 Vinícius De Moraes                 3
# 105                                     Zeca Pagodinho                 3
# 106                                         Body Count                 2
# 107                        Chico Science & Nação Zumbi                 2
# 108                                       Cidade Negra                 2
# 109                                    David Coverdale                 2
# 110                             Emerson String Quartet                 2
# 111                                 Funk Como Le Gusta                 2
# 112                                        Gonzaguinha                 2
# 113                                               Lost                 2
# 114                                   Maurizio Pollini                 2
# 115                                        Planet Hemp                 2
# 116  Academy of St. Martin in the Fields & Sir Nevi...                 1
# 117                               Battlestar Galactica                 1
# 118      Berliner Philharmoniker & Herbert Von Karajan                 1
# 119                                     Dread Zeppelin                 1
# 120                                          Falamansa                 1
# 121                                       James Levine                 1
# 122                                       Marcos Valle                 1
# 123                                             Olodum                 1
# 124                            Os Paralamas Do Sucesso                 1
# 125                          Scholars Baroque Ensemble                 1
# 126         The 12 Cellists of The Berlin Philharmonic                 1
# 127                                 The King's Singers                 1
# 128                                     Wilhelm Kempff                 1
# 129                                     Yehudi Menuhin                 1
#
# [130 rows x 2 columns]

# %% [markdown]
# ### list top 5 albums, as calculated by the number of times a track from that album has been purchased. Your query should return the following columns, in order:
# - **album**, the title of the album
# - **artist**, the artist who produced the album
# - **tracks_purchased** the total number of tracks purchased from that album

# %%
q4 = '''
SELECT 
    ta.title album,
    ta.name artist,
    COUNT(*) tracks_purchased
FROM invoice_line il
INNER JOIN (
            SELECT
                al.title,
                ar.name,
                t.track_id
            FROM track t
            INNER JOIN album al ON al.album_id = t.album_id
            INNER JOIN artist ar ON ar.artist_id = al.artist_id
            ) ta 
            ON il.track_id = ta.track_id
GROUP BY 1
ORDER BY 3 DESC LIMIT 5;
'''
pd.read_sql_query(q4,conn)
# Out:
#                   album            artist  tracks_purchased
# 0  Are You Experienced?      Jimi Hendrix               187
# 1              Faceless          Godsmack                96
# 2             Mezmerize  System Of A Down                93
# 3              Get Born               JET                90
# 4             The Doors         The Doors                83

# %% [markdown]
# # Recursive Joins
#
# Write a query that returns information about each employer and their supervisor. Your query should return the following columns, in order:
# - **employee_name** - containing the first_name and last_name columns separated by a space, eg Luke Skywalker
# - **employee_title** - the title of that employee
# - **supervisor_name** - the first and last name of the person the employee reports to, in the same format as    **employee_name**
# - **supervisor_title** - the title of the person the employee reports to
# - The report should include employees even if they do not report to another employee.

# %%
q5 = '''
SELECT
    e1.first_name || " " || e1.last_name employee_name,
    e1.title employee_title,
    e2.first_name || " " || e2.last_name supervisor_name,
    e2.title supervisor_title
FROM employee e1 
LEFT JOIN employee e2 on e1.reports_to = e2.employee_id
'''
pd.read_sql_query(q5,conn)
# Out:
#       employee_name       employee_title   supervisor_name supervisor_title
# 0      Andrew Adams      General Manager              None             None
# 1     Nancy Edwards        Sales Manager      Andrew Adams  General Manager
# 2      Jane Peacock  Sales Support Agent     Nancy Edwards    Sales Manager
# 3     Margaret Park  Sales Support Agent     Nancy Edwards    Sales Manager
# 4     Steve Johnson  Sales Support Agent     Nancy Edwards    Sales Manager
# 5  Michael Mitchell           IT Manager      Andrew Adams  General Manager
# 6       Robert King             IT Staff  Michael Mitchell       IT Manager
# 7    Laura Callahan             IT Staff  Michael Mitchell       IT Manager

# %% [markdown]
# # Pattern Matching Using Like
# Write a query that finds the contact details a customer with a first_name containing Belle from the database.
# Your query should include the following columns, in order:
# - **first_name**
# - **last_name**
# - **phone**

# %%
q6 = '''
SELECT
    first_name,
    last_name,
    phone
FROM customer 
WHERE first_name LIKE "%belle"
'''
pd.read_sql_query(q6,conn)
# Out:
#   first_name last_name               phone
# 0   Isabelle   Mercier  +33 03 80 73 66 99

# %% [markdown]
# # Generating Columns With The Case Statement
#
# - Write a query that summarizes the purchases of each customer. For the purposes of this exercise, we do not have any two customers with the same name.
# - Your query should include the following columns, in order:
#     - **customer_name** - containing the first_name and last_name columns separated by a space, eg Luke Skywalker.
#     - **number_of_purchases**, counting the number of purchases made by each customer.
#     - **total_spent** - the sum of customers total purchases made by each customer.
#     - **customer_category** - a column that categorizes the customer based on their total purchases. The column should contain the following values:
#         - **small spender** - If the customer's total purchases are less than \$40.
#         - **big spender** - If the customer's total purchases are greater than \$100.
#         - **regular** - If the customer's total purchases are between \$40 and \$100 (inclusive).
# - Order your results by the customer_name column.

# %%
q7 = '''
SELECT
   c.first_name || " " || c.last_name customer_name,
   COUNT(i.invoice_id) number_of_purchases,
   SUM(i.total) total_spent,
   CASE
       WHEN sum(i.total) < 40 THEN 'small spender'
       WHEN sum(i.total) > 100 THEN 'big spender'
       ELSE 'regular'
       END
       AS customer_category
FROM invoice i
INNER JOIN customer c ON i.customer_id = c.customer_id
GROUP BY 1 ORDER BY 1;
'''
pd.read_sql_query(q7,conn)
# Out:
#             customer_name  number_of_purchases  total_spent customer_category
# 0          Aaron Mitchell                    8        70.29           regular
# 1         Alexandre Rocha                   10        69.30           regular
# 2           Astrid Gruber                    9        69.30           regular
# 3            Bjørn Hansen                    9        72.27           regular
# 4         Camille Bernard                    9        79.20           regular
# 5            Daan Peeters                    7        60.39           regular
# 6              Dan Miller                   12        95.04           regular
# 7         Diego Gutiérrez                    5        39.60     small spender
# 8      Dominique Lefebvre                    9        72.27           regular
# 9         Eduardo Martins                   12        60.39           regular
# 10         Edward Francis                   13        91.08           regular
# 11         Ellie Sullivan                   12        75.24           regular
# 12             Emma Jones                    8        68.31           regular
# 13          Enrique Muñoz                   11        98.01           regular
# 14         Fernanda Ramos                   15       106.92       big spender
# 15           Frank Harris                    8        74.25           regular
# 16          Frank Ralston                    8        71.28           regular
# 17  František Wichterlová                   18       144.54       big spender
# 18      François Tremblay                    9        99.99           regular
# 19        Fynn Zimmermann                   10        94.05           regular
# 20       Hannah Schneider                   11        85.14           regular
# 21        Heather Leacock                   12        92.07           regular
# 22            Helena Holý                   12       128.70       big spender
# 23          Hugh O'Reilly                   13       114.84       big spender
# 24       Isabelle Mercier                   12        73.26           regular
# 25             Jack Smith                   12        98.01           regular
# 26      Jennifer Peterson                    9        66.33           regular
# 27       Joakim Johansson                   10        75.24           regular
# 28  Johannes Van der Berg                   10        65.34           regular
# 29            John Gordon                   10        66.33           regular
# 30         João Fernandes                   13       102.96       big spender
# 31          Julia Barnett                   10        72.27           regular
# 32           Kara Nielsen                   10        37.62     small spender
# 33            Kathy Chase                   11        91.08           regular
# 34        Ladislav Kovács                   10        78.21           regular
# 35          Leonie Köhler                   11        82.17           regular
# 36          Lucas Mancini                    9        50.49           regular
# 37             Luis Rojas                   13        97.02           regular
# 38         Luís Gonçalves                   13       108.90       big spender
# 39       Madalena Sampaio                   16        82.17           regular
# 40           Manoj Pareek                   13       111.87       big spender
# 41            Marc Dubois                    9        64.35           regular
# 42           Mark Philips                   10        29.70     small spender
# 43            Mark Taylor                   10        81.18           regular
# 44            Martha Silk                   11        62.37           regular
# 45        Michelle Brooks                    8        79.20           regular
# 46        Niklas Schröder                    9        73.26           regular
# 47           Patrick Gray                    9        84.15           regular
# 48            Phil Hughes                   11        98.01           regular
# 49        Puja Srivastava                    8        71.28           regular
# 50     Richard Cunningham                   12        86.13           regular
# 51           Robert Brown                    4        40.59           regular
# 52        Roberto Almeida                   11        82.17           regular
# 53       Stanisław Wójcik                   10        76.23           regular
# 54           Steve Murray                    9        79.20           regular
# 55       Terhi Hämäläinen                   11        79.20           regular
# 56              Tim Goyer                    9        54.45           regular
# 57         Victor Stevens                   10        76.23           regular
# 58           Wyatt Girard                   11        99.99           regular

# %% [markdown]
# # The With Clause
# - Create a query that shows summary data about the playlists in the Chinook database:
#     - Use a WITH clause to create a named subquery with the following info:
#         - The unique ID for the playlist.
#         - The name of the playlist.
#         - The name of each track from the playlist.
#         - The length of the each track in seconds.
#     - Your final table should have the following columns, in order:
#         - **playlist_id** - the unique ID for the playlist.
#         - **playlist_name** - The name of the playlist.
#         - **number_of_tracks** - A count of the number of tracks in the playlist.
#         - **length_seconds** - The sum of the length of the playlist in seconds.

# %%
q8 = '''
WITH playlist_info AS
    (
     SELECT
         p.playlist_id,
         p.name playlist_name,
         t.name track_name,
         (t.milliseconds / 1000) length_seconds
     FROM playlist p
     INNER JOIN playlist_track pt ON pt.playlist_id = p.playlist_id
     INNER JOIN track t ON t.track_id = pt.track_id
    )

SELECT
    playlist_id,
    playlist_name,
    COUNT(track_name) number_of_tracks,
    SUM(length_seconds) length_seconds
FROM playlist_info
GROUP BY 1, 2;
'''
pd.read_sql_query(q8,conn)
# Out:
#     playlist_id               playlist_name  number_of_tracks  length_seconds
# 0             1                       Music              3290          876049
# 1             3                    TV Shows               213          500987
# 2             5                  90’s Music              1477          397970
# 3             8                       Music              3290          876049
# 4             9                Music Videos                 1             294
# 5            10                    TV Shows               213          500987
# 6            11             Brazilian Music                39            9464
# 7            12                   Classical                75           21736
# 8            13   Classical 101 - Deep Cuts                25            6742
# 9            14  Classical 101 - Next Steps                25            7565
# 10           15  Classical 101 - The Basics                25            7429
# 11           16                      Grunge                15            4114
# 12           17         Heavy Metal Classic                26            8189
# 13           18                 On-The-Go 1                 1             197

# %% [markdown]
# # Creating Views
# - Create a view called **customer_gt_90_dollars**:
#     - The view should contain the columns from **customers**, in their original order.
#     - The view should contain only customers who have purchased more than \$90 in tracks from the store.
# - After the SQL query that creates the view, write a second query to display your newly created view: **SELECT \* FROM chinook.customer_gt_90_dollars**;.
#     - Make sure you use a semicolon **(;)** to indicate the end of each query.

# %%
q9 = '''
CREATE VIEW customer_usa AS 
     SELECT * FROM customer
     WHERE country = "USA";
'''

q10 = '''
CREATE VIEW customer_gt_90_dollars AS
    SELECT 
        c.* 
    FROM customer c
    INNER JOIN invoice i ON c.customer_id = i.customer_id
    GROUP BY c.customer_id 
    HAVING SUM(i.total) > 90;
'''

q11 = ' SELECT * FROM customer_gt_90_dollars'

pd.read_sql_query(q11,conn)
# Out:
#     customer_id first_name    last_name  \
# 0             1       Luís    Gonçalves
# 1             3   François     Tremblay
# 2             5  František  Wichterlová
# 3             6     Helena         Holý
# 4            13   Fernanda        Ramos
# 5            17       Jack        Smith
# 6            20        Dan       Miller
# 7            21      Kathy        Chase
# 8            22    Heather      Leacock
# 9            30     Edward      Francis
# 10           34       João    Fernandes
# 11           37       Fynn   Zimmermann
# 12           42      Wyatt       Girard
# 13           46       Hugh     O'Reilly
# 14           50    Enrique        Muñoz
# 15           53       Phil       Hughes
# 16           57       Luis        Rojas
# 17           58      Manoj       Pareek
#
#                                              company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               None
# 2                                   JetBrains s.r.o.
# 3                                               None
# 4                                               None
# 5                              Microsoft Corporation
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
# 10                                              None
# 11                                              None
# 12                                              None
# 13                                              None
# 14                                              None
# 15                                              None
# 16                                              None
# 17                                              None
#
#                             address                 city   state  \
# 0   Av. Brigadeiro Faria Lima, 2170  São José dos Campos      SP
# 1                 1498 rue Bélanger             Montréal      QC
# 2                     Klanova 9/506               Prague    None
# 3                     Rilská 3174/6               Prague    None
# 4                      Qe 7 Bloco G             Brasília      DF
# 5                   1 Microsoft Way              Redmond      WA
# 6              541 Del Medio Avenue        Mountain View      CA
# 7                  801 W 4th Street                 Reno      NV
# 8                  120 S Orange Ave              Orlando      FL
# 9                  230 Elgin Street               Ottawa      ON
# 10               Rua da Assunção 53               Lisbon    None
# 11                 Berger Straße 10            Frankfurt    None
# 12           9, Place Louis Barthou             Bordeaux    None
# 13                 3 Chatham Street               Dublin  Dublin
# 14               C/ San Bernardo 85               Madrid    None
# 15                     113 Lupus St               London    None
# 16                  Calle Lira, 198             Santiago    None
# 17              12,Community Centre                Delhi    None
#
#            country postal_code               phone                 fax  \
# 0           Brazil   12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1           Canada     H2G 1A7   +1 (514) 721-4711                None
# 2   Czech Republic       14700    +420 2 4172 5555    +420 2 4172 5555
# 3   Czech Republic       14300    +420 2 4177 0449                None
# 4           Brazil   71020-677  +55 (61) 3363-5547  +55 (61) 3363-7855
# 5              USA  98052-8300   +1 (425) 882-8080   +1 (425) 882-8081
# 6              USA   94040-111   +1 (650) 644-3358                None
# 7              USA       89503   +1 (775) 223-7665                None
# 8              USA       32801   +1 (407) 999-7788                None
# 9           Canada     K2P 1L7   +1 (613) 234-3322                None
# 10        Portugal        None  +351 (213) 466-111                None
# 11         Germany       60316    +49 069 40598889                None
# 12          France       33000  +33 05 56 96 96 96                None
# 13         Ireland        None     +353 01 6792424                None
# 14           Spain       28015     +34 914 454 454                None
# 15  United Kingdom    SW1V 3EN   +44 020 7976 5722                None
# 16           Chile        None   +56 (0)2 635 4444                None
# 17           India      110017   +91 0124 39883988                None
#
#                        email  support_rep_id
# 0       luisg@embraer.com.br               3
# 1        ftremblay@gmail.com               3
# 2   frantisekw@jetbrains.com               4
# 3            hholy@gmail.com               5
# 4   fernadaramos4@uol.com.br               4
# 5    jacksmith@microsoft.com               5
# 6        dmiller@comcast.com               4
# 7        kachase@hotmail.com               5
# 8         hleacock@gmail.com               4
# 9        edfrancis@yachoo.ca               3
# 10       jfernandes@yahoo.pt               4
# 11      fzimmermann@yahoo.de               3
# 12     wyatt.girard@yahoo.fr               3
# 13      hughoreilly@apple.ie               3
# 14    enrique_munoz@yahoo.es               5
# 15     phil.hughes@gmail.com               3
# 16        luisrojas@yahoo.cl               5
# 17   manoj.pareek@rediff.com               3

# %% [markdown]
# # Combining Rows With Union
# Use **UNION** to produce table of customers in the USA or have spent more than $90, using the **customer_usa** and **customer_gt_90_dollars** views:
# - The result should contain the columns from customers, in their original order.

# %%
q12 = '''
SELECT * FROM customer_usa
UNION
Select * FROM customer_gt_90_dollars
'''
pd.read_sql_query(q12,conn)
# Out:
#     customer_id first_name    last_name  \
# 0             1       Luís    Gonçalves
# 1             3   François     Tremblay
# 2             5  František  Wichterlová
# 3             6     Helena         Holý
# 4            13   Fernanda        Ramos
# 5            16      Frank       Harris
# 6            17       Jack        Smith
# 7            18   Michelle       Brooks
# 8            19        Tim        Goyer
# 9            20        Dan       Miller
# 10           21      Kathy        Chase
# 11           22    Heather      Leacock
# 12           23       John       Gordon
# 13           24      Frank      Ralston
# 14           25     Victor      Stevens
# 15           26    Richard   Cunningham
# 16           27    Patrick         Gray
# 17           28      Julia      Barnett
# 18           30     Edward      Francis
# 19           34       João    Fernandes
# 20           37       Fynn   Zimmermann
# 21           42      Wyatt       Girard
# 22           46       Hugh     O'Reilly
# 23           50    Enrique        Muñoz
# 24           53       Phil       Hughes
# 25           57       Luis        Rojas
# 26           58      Manoj       Pareek
#
#                                              company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               None
# 2                                   JetBrains s.r.o.
# 3                                               None
# 4                                               None
# 5                                        Google Inc.
# 6                              Microsoft Corporation
# 7                                               None
# 8                                         Apple Inc.
# 9                                               None
# 10                                              None
# 11                                              None
# 12                                              None
# 13                                              None
# 14                                              None
# 15                                              None
# 16                                              None
# 17                                              None
# 18                                              None
# 19                                              None
# 20                                              None
# 21                                              None
# 22                                              None
# 23                                              None
# 24                                              None
# 25                                              None
# 26                                              None
#
#                             address                 city   state  \
# 0   Av. Brigadeiro Faria Lima, 2170  São José dos Campos      SP
# 1                 1498 rue Bélanger             Montréal      QC
# 2                     Klanova 9/506               Prague    None
# 3                     Rilská 3174/6               Prague    None
# 4                      Qe 7 Bloco G             Brasília      DF
# 5         1600 Amphitheatre Parkway        Mountain View      CA
# 6                   1 Microsoft Way              Redmond      WA
# 7                      627 Broadway             New York      NY
# 8                   1 Infinite Loop            Cupertino      CA
# 9              541 Del Medio Avenue        Mountain View      CA
# 10                 801 W 4th Street                 Reno      NV
# 11                 120 S Orange Ave              Orlando      FL
# 12                  69 Salem Street               Boston      MA
# 13            162 E Superior Street              Chicago      IL
# 14            319 N. Frances Street              Madison      WI
# 15              2211 W Berry Street           Fort Worth      TX
# 16                  1033 N Park Ave               Tucson      AZ
# 17                      302 S 700 E       Salt Lake City      UT
# 18                 230 Elgin Street               Ottawa      ON
# 19               Rua da Assunção 53               Lisbon    None
# 20                 Berger Straße 10            Frankfurt    None
# 21           9, Place Louis Barthou             Bordeaux    None
# 22                 3 Chatham Street               Dublin  Dublin
# 23               C/ San Bernardo 85               Madrid    None
# 24                     113 Lupus St               London    None
# 25                  Calle Lira, 198             Santiago    None
# 26              12,Community Centre                Delhi    None
#
#            country postal_code               phone                 fax  \
# 0           Brazil   12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1           Canada     H2G 1A7   +1 (514) 721-4711                None
# 2   Czech Republic       14700    +420 2 4172 5555    +420 2 4172 5555
# 3   Czech Republic       14300    +420 2 4177 0449                None
# 4           Brazil   71020-677  +55 (61) 3363-5547  +55 (61) 3363-7855
# 5              USA  94043-1351   +1 (650) 253-0000   +1 (650) 253-0000
# 6              USA  98052-8300   +1 (425) 882-8080   +1 (425) 882-8081
# 7              USA  10012-2612   +1 (212) 221-3546   +1 (212) 221-4679
# 8              USA       95014   +1 (408) 996-1010   +1 (408) 996-1011
# 9              USA   94040-111   +1 (650) 644-3358                None
# 10             USA       89503   +1 (775) 223-7665                None
# 11             USA       32801   +1 (407) 999-7788                None
# 12             USA        2113   +1 (617) 522-1333                None
# 13             USA       60611   +1 (312) 332-3232                None
# 14             USA       53703   +1 (608) 257-0597                None
# 15             USA       76110   +1 (817) 924-7272                None
# 16             USA       85719   +1 (520) 622-4200                None
# 17             USA       84102   +1 (801) 531-7272                None
# 18          Canada     K2P 1L7   +1 (613) 234-3322                None
# 19        Portugal        None  +351 (213) 466-111                None
# 20         Germany       60316    +49 069 40598889                None
# 21          France       33000  +33 05 56 96 96 96                None
# 22         Ireland        None     +353 01 6792424                None
# 23           Spain       28015     +34 914 454 454                None
# 24  United Kingdom    SW1V 3EN   +44 020 7976 5722                None
# 25           Chile        None   +56 (0)2 635 4444                None
# 26           India      110017   +91 0124 39883988                None
#
#                        email  support_rep_id
# 0       luisg@embraer.com.br               3
# 1        ftremblay@gmail.com               3
# 2   frantisekw@jetbrains.com               4
# 3            hholy@gmail.com               5
# 4   fernadaramos4@uol.com.br               4
# 5         fharris@google.com               4
# 6    jacksmith@microsoft.com               5
# 7          michelleb@aol.com               3
# 8           tgoyer@apple.com               3
# 9        dmiller@comcast.com               4
# 10       kachase@hotmail.com               5
# 11        hleacock@gmail.com               4
# 12    johngordon22@yahoo.com               4
# 13        fralston@gmail.com               3
# 14        vstevens@yahoo.com               5
# 15  ricunningham@hotmail.com               4
# 16      patrick.gray@aol.com               4
# 17       jubarnett@gmail.com               5
# 18       edfrancis@yachoo.ca               3
# 19       jfernandes@yahoo.pt               4
# 20      fzimmermann@yahoo.de               3
# 21     wyatt.girard@yahoo.fr               3
# 22      hughoreilly@apple.ie               3
# 23    enrique_munoz@yahoo.es               5
# 24     phil.hughes@gmail.com               3
# 25        luisrojas@yahoo.cl               5
# 26   manoj.pareek@rediff.com               3

# %% [markdown]
# # Combining Rows using Intersect and Except
# - Write a query that works out how many customers that are in the USA and have purchased more than \$90 are assigned to each sales support agent. For the purposes of this exercise, no two employees have the same name.
# - Your result should have the following columns, in order:
#     - **employee_name** - The first_name and last_name of the employee separated by a space, eg **Luke Skywalker**.
#     - **customers_usa_gt_90** - The number of customer assigned to that employee that are both from the USA and have have purchased more than $90 worth of tracks.
# - The result should include all employees with the title **"Sales Support Agent"**, but not employees with any other title.
# - Order your results by the **employee_name column**.

# %%
q13 = '''
WITH customers_usa_gt_90 AS
    (
     SELECT * FROM customer_usa

     INTERSECT

     SELECT * FROM customer_gt_90_dollars
    )

SELECT
    e.first_name || " " || e.last_name employee_name,
    COUNT(c.customer_id) customers_usa_gt_90
FROM employee e
LEFT JOIN customers_usa_gt_90 c ON c.support_rep_id = e.employee_id
WHERE e.title = 'Sales Support Agent'
GROUP BY 1 ORDER BY 1;
'''
pd.read_sql_query(q13,conn)
# Out:
#    employee_name  customers_usa_gt_90
# 0   Jane Peacock                    0
# 1  Margaret Park                    2
# 2  Steve Johnson                    2

# %% [markdown]
# # Multiple Named Subqueries
# - Write a query that uses multiple named subqueries in a **WITH** clause to gather total sales data on customers from India:
#     - The first named subquery should return all customers that are from India.
#     - The second named subquery should calculate the sum total for every customer.
#     - The main query should join the two named subqueries, resulting in the following final columns:
#         - **customer_name** - The first_name and last_name of the customer, separated by a space, eg **Luke Skywalker**.
#         - **total_purchases** - The total amount spent on purchases by that customer.

# %%
q14 = '''
WITH
    customers_india AS
        (
        SELECT * FROM customer
        WHERE country = "India"
        ),
    sales_per_customer AS
        (
         SELECT
             customer_id,
             SUM(total) total
         FROM invoice
         GROUP BY 1
        )

SELECT
    ci.first_name || " " || ci.last_name customer_name,
    spc.total total_purchases
FROM customers_india ci
INNER JOIN sales_per_customer spc ON ci.customer_id = spc.customer_id
'''
pd.read_sql_query(q14,conn)
# Out:
#      customer_name  total_purchases
# 0     Manoj Pareek           111.87
# 1  Puja Srivastava            71.28

# %% [markdown]
# # Each Country's Best Customer
# - Create a query to find the customer from each country that has spent the most money at our store. Your query should return the following columns, in order:
#     - **country** - The name of each country that we have a customer from.
#     - **customer_name** - The first_name and last_name of the customer from that country with the most total purchases, separated by a space, eg Luke Skywalker.
#     - **total_purchased** - The total dollar amount that customer has purchased.
# - The rows should be order by the country column in alphabetical order.

# %%
q15 = '''
WITH customer_info AS
(
    SELECT 
        c.first_name || " " || c.last_name customer_name,
        c.country,
        sum(i.total) total_purchased
    FROM customer c
    INNER JOIN invoice i ON c.customer_id = i.customer_id
    GROUP BY 1
)
SELECT 
    country,
    customer_name,
    MAX(total_purchased) total_purchased
FROM customer_info
GROUP BY 1 ORDER BY 1
'''
pd.read_sql_query(q15,conn)
# Out:
#            country          customer_name  total_purchased
# 0        Argentina        Diego Gutiérrez            39.60
# 1        Australia            Mark Taylor            81.18
# 2          Austria          Astrid Gruber            69.30
# 3          Belgium           Daan Peeters            60.39
# 4           Brazil         Luís Gonçalves           108.90
# 5           Canada      François Tremblay            99.99
# 6            Chile             Luis Rojas            97.02
# 7   Czech Republic  František Wichterlová           144.54
# 8          Denmark           Kara Nielsen            37.62
# 9          Finland       Terhi Hämäläinen            79.20
# 10          France           Wyatt Girard            99.99
# 11         Germany        Fynn Zimmermann            94.05
# 12         Hungary        Ladislav Kovács            78.21
# 13           India           Manoj Pareek           111.87
# 14         Ireland          Hugh O'Reilly           114.84
# 15           Italy          Lucas Mancini            50.49
# 16     Netherlands  Johannes Van der Berg            65.34
# 17          Norway           Bjørn Hansen            72.27
# 18          Poland       Stanisław Wójcik            76.23
# 19        Portugal         João Fernandes           102.96
# 20           Spain          Enrique Muñoz            98.01
# 21          Sweden       Joakim Johansson            75.24
# 22             USA             Jack Smith            98.01
# 23  United Kingdom            Phil Hughes            98.01
