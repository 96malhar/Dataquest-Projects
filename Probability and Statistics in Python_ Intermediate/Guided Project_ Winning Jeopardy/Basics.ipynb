# %% [markdown]
# # Jeopardy Questions

# %%
import pandas as pd
jeopardy = pd.read_csv('jeopardy.csv')
jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
#some columns have spaces in the front
print(jeopardy.columns)
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
# strip white spaces
jeopardy.columns = [text.strip() for text in jeopardy.columns]

print(jeopardy.columns)
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %% [markdown]
# # Normalizing text
# Remove punctuations from **Question** and **Answer** columns and convert the text to lower case

# %%
from string import punctuation

def normalize_text(text):
    # convert to lowercase.
    text = text.lower()
    # Remove punctuations.
    text = text.translate(str.maketrans('', '', punctuation))
    
    return text

jeopardy['clean_question'] = jeopardy['Question'].apply(normalize_text)
jeopardy['clean_answer'] = jeopardy['Answer'].apply(normalize_text)

jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
#
#                                       clean_question clean_answer
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona
# 3  in 1963 live on the art linkletter show this c...    mcdonalds
# 4  signer of the dec of indep framer of the const...   john adams

# %% [markdown]
# # Normalizing columns
#  - convert the **Value** column to numeric.
#  - convert the **Air Date** column to datetime.

# %%
def normalize_value(text):
    
    #remove punctuation from value.
    text = text.translate(str.maketrans('','',punctuation))
    try:
        text = int(text)
    except Exception:
        text = 0
       
    return text

jeopardy['clean_value'] = jeopardy['Value'].apply(normalize_value)

# convert Air Date to datetime format.
jeopardy['Air Date'] = pd.to_datetime(jeopardy['Air Date'])

jeopardy.iloc[30:120]
# Out:
#      Show Number   Air Date             Round                      Category  \
# 30          4680 2004-12-31  Double Jeopardy!  PRESIDENTIAL STATES OF BIRTH
# 31          4680 2004-12-31  Double Jeopardy!                AIRLINE TRAVEL
# 32          4680 2004-12-31  Double Jeopardy!        THAT OLD-TIME RELIGION
# 33          4680 2004-12-31  Double Jeopardy!                MUSICAL TRAINS
# 34          4680 2004-12-31  Double Jeopardy!                   "X"s & "O"s
# 35          4680 2004-12-31  Double Jeopardy!  PRESIDENTIAL STATES OF BIRTH
# 36          4680 2004-12-31  Double Jeopardy!                AIRLINE TRAVEL
# 37          4680 2004-12-31  Double Jeopardy!        THAT OLD-TIME RELIGION
# 38          4680 2004-12-31  Double Jeopardy!                MUSICAL TRAINS
# 39          4680 2004-12-31  Double Jeopardy!                   "X"s & "O"s
# 40          4680 2004-12-31  Double Jeopardy!    DR. SEUSS AT THE MULTIPLEX
# 41          4680 2004-12-31  Double Jeopardy!                AIRLINE TRAVEL
# 42          4680 2004-12-31  Double Jeopardy!        THAT OLD-TIME RELIGION
# 43          4680 2004-12-31  Double Jeopardy!                MUSICAL TRAINS
# 44          4680 2004-12-31  Double Jeopardy!                   "X"s & "O"s
# 45          4680 2004-12-31  Double Jeopardy!    DR. SEUSS AT THE MULTIPLEX
# 46          4680 2004-12-31  Double Jeopardy!                AIRLINE TRAVEL
# 47          4680 2004-12-31  Double Jeopardy!        THAT OLD-TIME RELIGION
# 48          4680 2004-12-31  Double Jeopardy!                MUSICAL TRAINS
# 49          4680 2004-12-31  Double Jeopardy!                   "X"s & "O"s
# 50          4680 2004-12-31  Double Jeopardy!    DR. SEUSS AT THE MULTIPLEX
# 51          4680 2004-12-31  Double Jeopardy!                AIRLINE TRAVEL
# 52          4680 2004-12-31  Double Jeopardy!        THAT OLD-TIME RELIGION
# 53          4680 2004-12-31  Double Jeopardy!                MUSICAL TRAINS
# 54          4680 2004-12-31  Double Jeopardy!                   "X"s & "O"s
# 55          4680 2004-12-31   Final Jeopardy!              THE SOLAR SYSTEM
# 56          5957 2010-07-06         Jeopardy!                 GEOGRAPHY "E"
# 57          5957 2010-07-06         Jeopardy!                  RADIO DISNEY
# 58          5957 2010-07-06         Jeopardy!                PARTS OF PEACH
# 59          5957 2010-07-06         Jeopardy!        BE FRUITFUL & MULTIPLY
# ..           ...        ...               ...                           ...
# 90          5957 2010-07-06  Double Jeopardy!                    NEWS TO ME
# 91          5957 2010-07-06  Double Jeopardy!             IN THE DICTIONARY
# 92          5957 2010-07-06  Double Jeopardy!                 SCIENCE CLASS
# 93          5957 2010-07-06  Double Jeopardy!                KIDS IN SPORTS
# 94          5957 2010-07-06  Double Jeopardy!                JUST THE FACTS
# 95          5957 2010-07-06  Double Jeopardy!                     SEE & SAY
# 96          5957 2010-07-06  Double Jeopardy!                    NEWS TO ME
# 97          5957 2010-07-06  Double Jeopardy!             IN THE DICTIONARY
# 98          5957 2010-07-06  Double Jeopardy!                 SCIENCE CLASS
# 99          5957 2010-07-06  Double Jeopardy!                KIDS IN SPORTS
# 100         5957 2010-07-06  Double Jeopardy!                JUST THE FACTS
# 101         5957 2010-07-06  Double Jeopardy!                     SEE & SAY
# 102         5957 2010-07-06  Double Jeopardy!                    NEWS TO ME
# 103         5957 2010-07-06  Double Jeopardy!             IN THE DICTIONARY
# 104         5957 2010-07-06  Double Jeopardy!                 SCIENCE CLASS
# 105         5957 2010-07-06  Double Jeopardy!                KIDS IN SPORTS
# 106         5957 2010-07-06  Double Jeopardy!                JUST THE FACTS
# 107         5957 2010-07-06  Double Jeopardy!                     SEE & SAY
# 108         5957 2010-07-06  Double Jeopardy!                    NEWS TO ME
# 109         5957 2010-07-06  Double Jeopardy!             IN THE DICTIONARY
# 110         5957 2010-07-06  Double Jeopardy!                 SCIENCE CLASS
# 111         5957 2010-07-06  Double Jeopardy!                KIDS IN SPORTS
# 112         5957 2010-07-06  Double Jeopardy!                JUST THE FACTS
# 113         5957 2010-07-06  Double Jeopardy!                     SEE & SAY
# 114         5957 2010-07-06  Double Jeopardy!                    NEWS TO ME
# 115         5957 2010-07-06  Double Jeopardy!             IN THE DICTIONARY
# 116         5957 2010-07-06   Final Jeopardy!                HISTORIC WOMEN
# 117         3751 2000-12-18         Jeopardy!        ROYAL FEMALE NICKNAMES
# 118         3751 2000-12-18         Jeopardy!             TV ACTORS & ROLES
# 119         3751 2000-12-18         Jeopardy!              TRAVEL & TOURISM
#
#       Value                                           Question  \
# 30     $400                                         California
# 31     $400  It can be a place to leave your puppy when you...
# 32     $400  He's considered the author of the Pentateuch, ...
# 33     $400  Steven Tyler of this band lent his steamin' vo...
# 34     $400  Around 100 A.D. Tacitus wrote a book on how th...
# 35     $800                         1 of the 2 born in Vermont
# 36     $800  When it began on Pan Am & Qantas in the late '...
# 37     $800  Ali, who married this man's daughter Fatima, i...
# 38     $800  During the 1954-1955 Sun sessions, Elvis climb...
# 39     $800  The shorter glass seen <a href="http://www.j-a...
# 40    $1200  <a href="http://www.j-archive.com/media/2004-1...
# 41   $2,000  In 2003 this airline agreed to buy KLM, creati...
# 42    $1200  Philadelphia got its start as a colony for thi...
# 43    $1200  This "Modern Girl" first hit the Billboard Top...
# 44    $1200  This stiff silken fabric is favored for bridal...
# 45    $1600  <a href="http://www.j-archive.com/media/2004-1...
# 46    $1600  In 2004 United launched this new service that ...
# 47    $1600  With Mary I's accession in 1553 he ran to Gene...
# 48    $1600  This band's "Train In Vain" was a hidden track...
# 49    $1600  Cross-country skiing is sometimes referred to ...
# 50    $2000  <a href="http://www.j-archive.com/media/2004-1...
# 51    $2000  In the seat pocket you'll find the catalog cal...
# 52   $3,200  In 1534 he & his buddy Francis Xavier founded ...
# 53    $2000  In 1961 James Brown announced "all aboard" for...
# 54    $2000  This 1797 imbroglio began when 3 French agents...
# 55     None  Objects that pass closer to the sun than Mercu...
# 56     $200     It's the largest kingdom in the United Kingdom
# 57     $200  "Party In The U.S.A." is by this singer who al...
# 58     $200  If this part of a peach is downy or fuzzy, the...
# 59     $200                                             4 x 12
# ..      ...                                                ...
# 90     $400  A 7.0 magnitude earthquake in this Caribbean c...
# 91     $400  It's the 4-letter name of the pleated skirt wo...
# 92     $800  During this plant process, carbon dioxide & wa...
# 93     $800  The perfect waves of New Zealand's Piha Beach ...
# 94     $800  This city, the seat of Clark County, Nevada, h...
# 95     $800  Say <a href="http://www.j-archive.com/media/20...
# 96     $800  This car company has been in the news for wide...
# 97     $800  As an adjective, it can mean proper; as a verb...
# 98    $1200  The wedge is an adaptation of the simple machi...
# 99    $1200  With a mighty leap of 5'1", David Mosely set t...
# 100   $1200  <a href="http://www.j-archive.com/media/2010-0...
# 101   $1200  Say the name of <a href="http://www.j-archive....
# 102   $1200  (<a href="http://www.j-archive.com/media/2010-...
# 103   $1200                     Maize is another word for this
# 104  $5,000  Of the 6 noble gases on the periodic table, it...
# 105   $1600  11-year-old Ashlyn White won a 2009 U.S. youth...
# 106   $1600  In 1751 the Penn Provincial Assembly placed th...
# 107   $1600  Say the name of <a href="http://www.j-archive....
# 108   $1600  In a surprise, Ted Kennedy's old Senate seat i...
# 109  $5,000  This word for someone who walks comes from the...
# 110   $2000  Lava & igneous rock are formed from this hot l...
# 111   $2000  This sport has an under-17 World Cup every 2 y...
# 112   $2000  He's the older son of Prince Charles and the l...
# 113   $2000  Say the name of <a href="http://www.j-archive....
# 114   $2000  Falcon Heene, who it turned out was safe at ho...
# 115   $2000  Kayak is an example of this, a word that reads...
# 116    None  She was born in Virginia around 1596 & died in...
# 117    $100  Prime Minister Tony Blair dubbed her "The Peop...
# 118    $100  Once Tommy Mullaney on "L.A. Law", John Spence...
# 119    $100  The Cinderella Castle Mystery Tour is a highli...
#
#                            Answer  \
# 30                          Nixon
# 31                       a kennel
# 32                          Moses
# 33                      Aerosmith
# 34                        oratory
# 35   Coolidge (or Chester Arthur)
# 36                 business class
# 37                       Muhammed
# 38            the "Mystery Train"
# 39               an old-fashioned
# 40                         Yertle
# 41                     Air France
# 42                    the Quakers
# 43                (Sheena) Easton
# 44                        organza
# 45                Mulberry Street
# 46                            Ted
# 47                    (John) Knox
# 48                      The Clash
# 49                             XC
# 50            Bartholomew Cubbins
# 51                           Mall
# 52          (St. Ignatius) Loyola
# 53                  "Night Train"
# 54                 the XYZ Affair
# 55                         Icarus
# 56                        England
# 57                    Miley Cyrus
# 58                       the skin
# 59                             48
# ..                            ...
# 90                          Haiti
# 91                         a kilt
# 92                 photosynthesis
# 93                        surfing
# 94                      Las Vegas
# 95                         Oregon
# 96                         Toyota
# 97                        correct
# 98                          plane
# 99                  the high jump
# 100             a German Shepherd
# 101                 the dragonfly
# 102                       Dracula
# 103                          corn
# 104                        helium
# 105                          judo
# 106              the Liberty Bell
# 107                       redwood
# 108                 Massachusetts
# 109                    pedestrian
# 110                         magma
# 111                        soccer
# 112                Prince William
# 113                 Ronald Reagan
# 114               the balloon boy
# 115                  a palindrome
# 116                    Pocahontas
# 117                Princess Diana
# 118                 The West Wing
# 119                         Tokyo
#
#                                         clean_question  \
# 30                                          california
# 31   it can be a place to leave your puppy when you...
# 32   hes considered the author of the pentateuch wh...
# 33   steven tyler of this band lent his steamin voc...
# 34   around 100 ad tacitus wrote a book on how this...
# 35                          1 of the 2 born in vermont
# 36   when it began on pan am  qantas in the late 70...
# 37   ali who married this mans daughter fatima is c...
# 38   during the 19541955 sun sessions elvis climbed...
# 39   the shorter glass seen a hrefhttpwwwjarchiveco...
# 40   a hrefhttpwwwjarchivecommedia20041231dj26mp3ri...
# 41   in 2003 this airline agreed to buy klm creatin...
# 42   philadelphia got its start as a colony for thi...
# 43   this modern girl first hit the billboard top 1...
# 44   this stiff silken fabric is favored for bridal...
# 45   a hrefhttpwwwjarchivecommedia20041231dj25mp3so...
# 46   in 2004 united launched this new service that ...
# 47   with mary is accession in 1553 he ran to genev...
# 48   this bands train in vain was a hidden track on...
# 49   crosscountry skiing is sometimes referred to b...
# 50   a hrefhttpwwwjarchivecommedia20041231dj24mp350...
# 51   in the seat pocket youll find the catalog call...
# 52   in 1534 he  his buddy francis xavier founded t...
# 53   in 1961 james brown announced all aboard for t...
# 54   this 1797 imbroglio began when 3 french agents...
# 55   objects that pass closer to the sun than mercu...
# 56       its the largest kingdom in the united kingdom
# 57   party in the usa is by this singer who also pl...
# 58   if this part of a peach is downy or fuzzy the ...
# 59                                              4 x 12
# ..                                                 ...
# 90   a 70 magnitude earthquake in this caribbean co...
# 91   its the 4letter name of the pleated skirt worn...
# 92   during this plant process carbon dioxide  wate...
# 93   the perfect waves of new zealands piha beach w...
# 94   this city the seat of clark county nevada has ...
# 95   say a hrefhttpwwwjarchivecommedia20100706dj27j...
# 96   this car company has been in the news for wide...
# 97   as an adjective it can mean proper as a verb t...
# 98   the wedge is an adaptation of the simple machi...
# 99   with a mighty leap of 51 david mosely set the ...
# 100  a hrefhttpwwwjarchivecommedia20100706dj14jpg t...
# 101  say the name of a hrefhttpwwwjarchivecommedia2...
# 102  a hrefhttpwwwjarchivecommedia20100706dj21wmvji...
# 103                     maize is another word for this
# 104  of the 6 noble gases on the periodic table it ...
# 105  11yearold ashlyn white won a 2009 us youth tit...
# 106  in 1751 the penn provincial assembly placed th...
# 107  say the name of a hrefhttpwwwjarchivecommedia2...
# 108  in a surprise ted kennedys old senate seat in ...
# 109  this word for someone who walks comes from the...
# 110  lava  igneous rock are formed from this hot li...
# 111  this sport has an under17 world cup every 2 ye...
# 112  hes the older son of prince charles and the la...
# 113  say the name of a hrefhttpwwwjarchivecommedia2...
# 114  falcon heene who it turned out was safe at hom...
# 115  kayak is an example of this a word that reads ...
# 116  she was born in virginia around 1596  died in ...
# 117  prime minister tony blair dubbed her the peopl...
# 118  once tommy mullaney on la law john spencer now...
# 119  the cinderella castle mystery tour is a highli...
#
#                    clean_answer  clean_value
# 30                        nixon          400
# 31                     a kennel          400
# 32                        moses          400
# 33                    aerosmith          400
# 34                      oratory          400
# 35   coolidge or chester arthur          800
# 36               business class          800
# 37                     muhammed          800
# 38            the mystery train          800
# 39              an oldfashioned          800
# 40                       yertle         1200
# 41                   air france         2000
# 42                  the quakers         1200
# 43                sheena easton         1200
# 44                      organza         1200
# 45              mulberry street         1600
# 46                          ted         1600
# 47                    john knox         1600
# 48                    the clash         1600
# 49                           xc         1600
# 50          bartholomew cubbins         2000
# 51                         mall         2000
# 52           st ignatius loyola         3200
# 53                  night train         2000
# 54               the xyz affair         2000
# 55                       icarus            0
# 56                      england          200
# 57                  miley cyrus          200
# 58                     the skin          200
# 59                           48          200
# ..                          ...          ...
# 90                        haiti          400
# 91                       a kilt          400
# 92               photosynthesis          800
# 93                      surfing          800
# 94                    las vegas          800
# 95                       oregon          800
# 96                       toyota          800
# 97                      correct          800
# 98                        plane         1200
# 99                the high jump         1200
# 100           a german shepherd         1200
# 101               the dragonfly         1200
# 102                     dracula         1200
# 103                        corn         1200
# 104                      helium         5000
# 105                        judo         1600
# 106            the liberty bell         1600
# 107                     redwood         1600
# 108               massachusetts         1600
# 109                  pedestrian         5000
# 110                       magma         2000
# 111                      soccer         2000
# 112              prince william         2000
# 113               ronald reagan         2000
# 114             the balloon boy         2000
# 115                a palindrome         2000
# 116                  pocahontas            0
# 117              princess diana          100
# 118               the west wing          100
# 119                       tokyo          100
#
# [90 rows x 10 columns]

# %%
jeopardy.dtypes
# Out:
# Show Number                int64
# Air Date          datetime64[ns]
# Round                     object
# Category                  object
# Value                     object
# Question                  object
# Answer                    object
# clean_question            object
# clean_answer              object
# clean_value                int64
# dtype: object

# %% [markdown]
# # Answer in questions
# we will count how many words in the answer match the words in the question.
# This will help us determine if it is necessary to study or one can guess the answer just by looking at the question.

# %%
def count_matches(row):
    
    # split question and answers ino seperate words.
    split_answer = row['clean_answer'].split(' ')
    split_question = row['clean_question'].split(' ')
    match_count = 0
    
    # check if 'the is present in answer list.
    if 'the' in split_answer:
        # if 'the' is present remove it from the answer list.
        split_answer = [word for word in split_answer if word != 'the']
    # check if length of list is 0    
    if len(split_answer) == 0:
        return 0

    # count the number of times each word in the answer appears in the question.
    for word in split_answer:
        if word in split_question:
            match_count += 1
    # percentage of words in split_answer that are present in split_question.    
    return match_count / len(split_answer) 

jeopardy['answer_in_question'] = jeopardy.apply(count_matches, axis=1)

jeopardy['answer_in_question'].mean()
# Out:
# 0.05973712438535688

# %% [markdown]
# Thus, on an average 6% of the words are common between the questions and the answers. This isn't a huge number, and means that we probably can't just hope that hearing a question will enable us to figure out the answer. We'll probably have to study.

# %% [markdown]
# # Recycled questions
# we want to see how often new questions are repeats of older ones.

# %%
# it is a list that calculates the proportion of total words in each question that are present in terms used.
question_overlap = []

#it is set that is used to store new words that occur in each question.
terms_used = set()
 
# iterating rows in jeopardy.
for i, row in jeopardy.iterrows():
    
    # split clean_question into individual words.
    split_question = row['clean_question'].split(' ')
    # only retaining words with length greater than 5.
    split_question = [word for word in split_question if len(word)>=6]
    
    match_count = 0
    
    # Iterating through split_question.
    for word in split_question:
        # check if word occurs in terms_used
        if word in terms_used:
            match_count += 1 # increment counter.
        # add each word in split_question to terms_used. set does not have duplicates.    
        terms_used.add(word)   
       
    # percentage of words in split_questions that are present in terms_used.
    if len(split_question) > 0:
        match_count /= len(split_question)
    
    question_overlap.append(match_count)

jeopardy['question_overlap'] = question_overlap
jeopardy['question_overlap'].mean()
# Out:
# 0.6919577992203563

# %% [markdown]
# ## Question overlap
# There is about 70% overlap between terms in new questions and terms in old questions. This only looks at a small set of questions, and it doesn't look at phrases, it looks at single terms. This makes it relatively insignificant, but it does mean that it's worth looking more into the recycling of questions.

# %% [markdown]
# # Low value vs high value questions

# %%
# classify rows based on their question value
def determine_value(row):
    # check value
    if row['clean_value'] > 800:
        value = 1
    else:
        value = 0
       
    return value

jeopardy['high_value'] = jeopardy.apply(determine_value, axis=1)

# %%
# count the number of times a term occurs in low value and high value questions.
def count_usage(term):
    
   # initialise counts.
    low_count = 0 # number of times the term occurs in low value question.
    high_count = 0 # number of times the term occurs in a high value question.
    
   # Iterate through rows.
    for i, row in jeopardy.iterrows():
        
        # split clean_question into individual words.
        split_question = row['clean_question'].split(' ')
        
        # check if term occurs in split_question.
        if term in split_question:
            
            # check value of the question
            if row['high_value'] == 1:
                high_count += 1 
            else:
                low_count += 1
                   
    return high_count, low_count       
            
#we only pass the first 5 terms for terms_used.
comparison_terms = list(terms_used)[:5]
observed_high_low_count = [count_usage(term) for term in comparison_terms]
observed_high_low_count
# Out:
# [(1, 0), (0, 1), (0, 1), (1, 5), (0, 2)]

# %% [markdown]
# # Applying the chi-squared test

# %%
from scipy.stats import chisquare
import numpy as np
# number of high value questions.
high_value_count = jeopardy[jeopardy["high_value"] == 1].shape[0]

# number of low value questions.
low_value_count = jeopardy[jeopardy["high_value"] == 0].shape[0]

chi_squared = []
for obs in observed_high_low_count:
    
    # total number of questions that the term occured in.
    total = sum(obs)
    
    # proportion of questions that the term occured in.
    total_prop = total / jeopardy.shape[0]
    
    # expected high value count.
    high_value_exp = total_prop * high_value_count
    
    # expected low value count.
    low_value_exp = total_prop * low_value_count
    
    observed = np.array([obs[0], obs[1]])
    expected = np.array([high_value_exp, low_value_exp])
    chi_squared.append(chisquare(observed, expected))

chi_squared
# Out:
# [Power_divergenceResult(statistic=2.4877921171956752, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=0.40196284612688399, pvalue=0.52607729857054686),
#  Power_divergenceResult(statistic=0.40196284612688399, pvalue=0.52607729857054686),
#  Power_divergenceResult(statistic=0.42281054506129573, pvalue=0.51553795812945302),
#  Power_divergenceResult(statistic=0.80392569225376798, pvalue=0.36992223780795708)]
